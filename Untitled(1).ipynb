# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import copy
from math import sqrt,ceil
from scipy.stats import linregress

# %%
directory = "Test Data/"
file = "REV2_FCC1_29_02_2024_vast_vermogen_40W"

# %%
data = np.genfromtxt(f'{directory}{file}', delimiter=',', dtype=None, encoding='latin1',filling_values=np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-84f2b5591232> in <module>
# ----> 1 data = np.genfromtxt(f'{directory}{file}', delimiter=',', dtype=None, encoding='latin1',filling_values=np.nan)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2120             # Raise an exception ?
#    2121             if invalid_raise:
# -> 2122                 raise ValueError(errmsg)
#    2123             # Issue a warning ?
#    2124             else:
#
# ValueError: Some errors were detected !
#     Line #30 (got 62 columns instead of 84)

# %%
print(data[0,3])
for i in range(len(data[0,:])):
    plt.plot(data[0:10000,i])
    plt.show()
#plt.plot(data[0:100000,13])
# Out:
# 0.2696

# %%
df = pd.read_csv(f'{directory}{file}' , delimiter=' ', 
                 na_values=['nan', 'NAN', 'NaN'],  # Strings die als NaN moeten worden geïnterpreteerd
                 thousands='.',  # Als komma's als duizendtalscheiders worden gebruikt
                 decimal=',',  # Als punten als decimaalteken worden gebruikt
                 #encoding='ISO-8859-1', 
                 #usecols=[1],  # Selecteer alleen de eerste kolom
                 skiprows=0)
# Out:
# C:\Users\bono\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,7,8,9,10,12,13,15,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         13:02:35  46955.559414  >04    0.2646  -31.698  1383.872  23.77 3.096  \
# 0       13:02:35   46955564764  >04      2696  -31.703   1384622   2387  3279
# 1       13:02:35   46955569414  >04      2746  -31.705   1385288   2395  3254
# 2       13:02:35   46955574408  >04      2794  -31.705   1385886   2403  3395
# 3       13:02:35   46955579407  >04      2844  -31.717   1386426   2411  3566
# 4       13:02:35   46955584762  >04      2894  -31.706   1386905   2418  3574
# ...          ...           ...  ...       ...      ...       ...    ...   ...
# 213020  13:40:58   49258159837  >04  23024153   -17243   1329160   2655   -84
# 213021  13:40:58   49258164833  >04  23024204   -16962   1308012   2655   -84
# 213022  13:40:58   49258170865  >04  23024258   -16624   1283738   2654   -83
# 213023  13:40:58   49258175911  >04  23024312   -16274   1257966   2655   -83
# 213024  13:40:58   49258181835  >04  23024365   -15897   1231046   2655   -84
#
#        14.564 24.559  ... 0.1  0.000.2 0.2 0.000.3  Unnamed: 22 Unnamed: 23  \
# 0       14597  24651  ...   0        0   0       0          NaN         NaN
# 1       14611  24744  ...   0        0   0       0          NaN         NaN
# 2       14676  24825  ...   0        0   0       0          NaN         NaN
# 3       14716  24903  ...   0        0   0       0          NaN         NaN
# 4       14708  24984  ...   0        0   0       0          NaN         NaN
# ...       ...    ...  ...  ..      ...  ..     ...          ...         ...
# 213020    489  11442  ...   0    25194   0       0          NaN         NaN
# 213021    495  11209  ...   0    25194   0       0          NaN         NaN
# 213022    497  10960  ...   0    25194   0       0          NaN         NaN
# 213023    502  10730  ...   0    25194   0       0          NaN         NaN
# 213024    501  10487  ...   0    25194   0       0          NaN         NaN
#
#         Unnamed: 24  Unnamed: 25  Unnamed: 26  <
# 0               NaN          NaN          NaN  <
# 1               NaN          NaN          NaN  <
# 2               NaN          NaN          NaN  <
# 3               NaN          NaN          NaN  <
# 4               NaN          NaN          NaN  <
# ...             ...          ...          ... ..
# 213020          NaN          NaN          NaN  <
# 213021          NaN          NaN          NaN  <
# 213022          NaN          NaN          NaN  <
# 213023          NaN          NaN          NaN  <
# 213024          NaN          NaN          NaN  <
#
# [213025 rows x 28 columns]

# %%
print(df.iloc[11,0])
plt.plot(df.iloc[:,1]-df.iloc[0,1])
print(df.iloc[:,1]-df.iloc[0,1])
# Out:
# 13:02:36
# 0                 0
# 1             92978
# 2            176987
# 3            289993
# 4            374089
#             ...
# 21296    2301976338
# 21297    2302073332
# 21298    2302170359
# 21299    2302298380
# 21300    2302373463
# Name: 46955.643412, Length: 21301, dtype: int64
